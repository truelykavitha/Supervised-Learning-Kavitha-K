# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Reading the Dataset to the Python Environment.

# %%
df = pd.read_excel("iris (1).xls")
df
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    NaN  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  NaN  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
np.mean(df,axis=0)
# Out:
# SL    5.855944
# SW    3.049306
# PL    3.756250
# PW    1.198667
# dtype: float64

# %%
np.min(df,axis=0)
# Out:
# SL                        4.3
# SW                        2.0
# PL                        1.0
# PW                        0.1
# Classification    Iris-setosa
# dtype: object

# %%
np.max(df,axis=0)
# Out:
# SL                           7.9
# SW                           4.4
# PL                           6.9
# PW                           2.5
# Classification    Iris-virginica
# dtype: object

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# Descriptional Statistics of the dataset grouped by the data feature classification before data cleaning

# %%
pd.set_option('display.max_columns', None)
df.groupby('Classification').describe()
# Out:
#                    SL                                                     SW  \
#                 count      mean       std  min    25%   50%   75%  max count
# Classification
# Iris-setosa      47.0  5.008511  0.360452  4.3  4.800  5.00  5.20  5.8  47.0
# Iris-versicolor  48.0  5.925000  0.522474  4.9  5.600  5.85  6.30  7.0  48.0
# Iris-virginica   48.0  6.616667  0.598343  5.6  6.275  6.50  6.95  7.9  49.0
#
#                                                                  PL            \
#                      mean       std  min  25%  50%   75%  max count      mean
# Classification
# Iris-setosa      3.408511  0.390557  2.3  3.1  3.4  3.65  4.4  48.0  1.468750
# Iris-versicolor  2.781250  0.315322  2.0  2.6  2.8  3.00  3.4  48.0  4.252083
# Iris-virginica   2.967347  0.322353  2.2  2.8  3.0  3.10  3.8  48.0  5.547917
#
#                                                          PW                   \
#                       std  min  25%   50%    75%  max count   mean       std
# ...

# %%
df.isna().sum()
# Out:
# SL                7
# SW                6
# PL                6
# PW                0
# Classification    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              143 non-null    float64
#  1   SW              144 non-null    float64
#  2   PL              144 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df['Classification'].value_counts()
# Out:
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: Classification, dtype: int64

# %%
df[df.duplicated()]
# Out:
#       SL   SW   PL   PW  Classification
# 34   4.9  3.1  1.5  0.1     Iris-setosa
# 37   4.9  3.1  1.5  0.1     Iris-setosa
# 142  5.8  2.7  5.1  1.9  Iris-virginica

# %% [markdown]
# Each Classification in the dataset iris is equally distributed but there are some missing values.
#
# Here we can see that the mean of SL of Iris-virginica is higher than both that of Iris-versicolor and Iris-setosa.
#
# But when we look into the mean value of SW, Iris-setosa has the highest mean value when compared to Iris-versicolor and Iris-virginica.
#
# Iris-setosa has the least mean value for PL when compared to other classifications.Iris-virginica has the highest value.
#
# Iris-virginica has the highest mean value for PW and Iris-setosa has the lowest value.

# %% [raw]
# Data Visualizations

# %%
plt.title('Count of Classification')
sns.countplot(x=df['Classification'])
# Out:
# <AxesSubplot:title={'center':'Count of Classification'}, xlabel='Classification', ylabel='count'>

# %%
sns.pairplot(df,hue='Classification')

# %% [markdown]
# # 2. Do necessary Pre-processing Steps:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              143 non-null    float64
#  1   SW              144 non-null    float64
#  2   PL              144 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isna().sum()
# Out:
# SL                7
# SW                6
# PL                6
# PW                0
# Classification    0
# dtype: int64

# %%
freqgraph=df.select_dtypes(include="float")
freqgraph.hist(figsize=(20,15))
plt.show()

# %% [markdown]
# Handling Missing Values

# %%
df['SL'] = df['SL'].fillna(df['PL'].mean())
df['SW'] = df['SW'].fillna(df['PL'].mean())
df['PL'] = df['PL'].fillna(df['PL'].mean())
df.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# Handling Outliers

# %%
fig, axes = plt.subplots(2, 2, figsize=(16,9))
sns.boxplot( y=df['PL'], x= 'Classification', data=df, orient='v' , ax=axes[0, 0])
sns.boxplot( y=df['PW'], x= 'Classification', data=df, orient='v' , ax=axes[0, 1])
sns.boxplot( y=df['SL'], x= 'Classification', data=df, orient='v' , ax=axes[1, 0])
sns.boxplot( y=df['SW'], x= 'Classification', data=df, orient='v' , ax=axes[1, 1])
plt.show()

# %%
for column in df.columns[0:4]:
    for classification in df["Classification"].unique():
        class_type = df[df["Classification"] == classification]
        Selected_column = class_type[column]
        q1 = Selected_column.quantile(0.25) # for select first quartile
        q3 = Selected_column.quantile(0.75) # for select third quartile
        iqr = q3 - q1 # this is interquartile range
        upper_limit = q3 + 1.5 * iqr
        lower_limit = q1 - 1.5 * iqr        
        outlierss = Selected_column[(Selected_column > upper_limit) | (Selected_column < lower_limit)].index # picking outliers' indeces
        print(outlierss)
        df.drop(index = outlierss, inplace=True) # dropping outliers
# Out:
# Int64Index([2, 21, 39], dtype='int64')
# Int64Index([51, 85], dtype='int64')
# Int64Index([106, 141], dtype='int64')
# Int64Index([], dtype='int64')
# Int64Index([72, 98], dtype='int64')
# Int64Index([], dtype='int64')
# Int64Index([22, 28, 42], dtype='int64')
# Int64Index([], dtype='int64')
# Int64Index([109, 147], dtype='int64')
# Int64Index([23, 43], dtype='int64')
# Int64Index([], dtype='int64')
# Int64Index([], dtype='int64')

# %%
fig, axes = plt.subplots(2, 2, figsize=(16,9))
sns.boxplot( y=df['PL'], x= 'Classification', data=df, orient='v', ax=axes[0, 0])
sns.boxplot( y=df['PW'], x= 'Classification', data=df, orient='v' , ax=axes[0, 1])
sns.boxplot( y=df['SL'], x= 'Classification', data=df, orient='v' , ax=axes[1, 0])
sns.boxplot( y=df['SW'], x= 'Classification', data=df, orient='v' , ax=axes[1, 1])
plt.show()

# %% [markdown]
# Label Encoding

# %%
df.Classification.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
label_en = LabelEncoder()
df['Classification'] = label_en.fit_transform(df['Classification'])

# %%
df
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2               0
# 1    4.9  3.0  1.4  0.2               0
# 3    4.6  3.1  1.5  0.2               0
# 4    5.0  3.6  1.4  0.2               0
# 5    5.4  3.9  1.7  0.4               0
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.3  5.7  2.5               2
# 145  6.7  3.0  5.2  2.3               2
# 146  6.3  2.5  5.0  1.9               2
# 148  6.2  3.4  5.4  2.3               2
# 149  5.9  3.0  5.1  1.8               2
#
# [134 rows x 5 columns]

# %%
corrmatrix = df.corr()
plt.subplots(figsize=(20,8))
sns.heatmap(corrmatrix,vmin=0.4,vmax=0.9,annot=True,linewidths=0.2,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
y = df['Classification']
x = df.drop('Classification',axis=1)

# %% [markdown]
# Feature Engineering

# %%
x['mean'] = x[['SW', 'SL', 'PW', 'PL']].mean(axis = 1)
x['sum'] = x[['SW', 'SL', 'PW', 'PL']].sum(axis = 1)
x['skew'] = x[['SW', 'SL', 'PW', 'PL']].skew(axis = 1)
x['kurt'] = x[['SW', 'SL', 'PW', 'PL']].kurt(axis = 1)

# %%
x.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'mean', 'sum', 'skew', 'kurt'], dtype='object')

# %% [markdown]
# Splitting the data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 2, test_size = 0.3)

# %% [markdown]
# standard Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %% [markdown]
# # 3. Find out which classification model gives the best result to predict iris species.(also do random forest algorithm).

# %% [markdown]
# building the Model-Logistic Regression Algorithm

# %%
from sklearn.linear_model import LogisticRegression
logit_model = LogisticRegression()
logit_model.fit(x_train, y_train)
y_pred = logit_model.predict(x_test)
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# %%
print("Accuracy is: ", accuracy_score(y_test,y_pred))
print("Precision is: ", precision_score(y_test,y_pred, average = 'micro'))
print("Recall is: ", recall_score(y_test,y_pred,  average = 'micro'))
print("F1 score is: ", f1_score(y_test,y_pred,  average = 'micro'))
# Out:
# Accuracy is:  1.0
# Precision is:  1.0
# Recall is:  1.0
# F1 score is:  1.0

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[16,  0,  0],
#        [ 0, 13,  0],
#        [ 0,  0, 12]], dtype=int64)

# %% [markdown]
# Building the Model---KNN Algorithm

# %%
from sklearn.neighbors import KNeighborsClassifier
acc_values = []
neighbors = np.arange(3,15)
for k in neighbors:
    classifier = KNeighborsClassifier(n_neighbors = k, metric='minkowski')
    classifier.fit(x_train, y_train)
    y_pred =  classifier.predict(x_test)
    acc = accuracy_score(y_test, y_pred)
    acc_values.append(acc)

# %%
acc_values
# Out:
# [0.9512195121951219,
#  0.975609756097561,
#  0.926829268292683,
#  0.975609756097561,
#  0.975609756097561,
#  0.975609756097561,
#  0.975609756097561,
#  0.975609756097561,
#  0.975609756097561,
#  0.975609756097561,
#  0.975609756097561,
#  0.975609756097561]

# %%
plt.plot(neighbors, acc_values, 'o-')
plt.xlabel('K values')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
classifier = KNeighborsClassifier(n_neighbors = 5, metric='minkowski')
classifier.fit(x_train, y_train)
y_pred =  classifier.predict(x_test)

# %%
print("Accuracy is: ", accuracy_score(y_test,y_pred))
print("Precision is: ", precision_score(y_test,y_pred, average = 'micro'))
print("Recall is: ", recall_score(y_test,y_pred,  average = 'micro'))
print("F1 score is: ", f1_score(y_test,y_pred,  average = 'micro'))
# Out:
# Accuracy is:  0.926829268292683
# Precision is:  0.926829268292683
# Recall is:  0.926829268292683
# F1 score is:  0.926829268292683

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[16,  0,  0],
#        [ 0, 10,  3],
#        [ 0,  0, 12]], dtype=int64)

# %% [markdown]
# building the Model-Decision Tree Algorithm

# %%
from sklearn.tree import DecisionTreeClassifier
dt_model =DecisionTreeClassifier()
dt_model.fit(x_train,y_train)
y_pred=dt_model.predict(x_test)

# %%
print("Accuracy is: ", accuracy_score(y_test,y_pred))
print("Precision is: ", precision_score(y_test,y_pred, average = 'micro'))
print("Recall is: ", recall_score(y_test,y_pred,  average = 'micro'))
print("F1 score is: ", f1_score(y_test,y_pred,  average = 'micro'))
# Out:
# Accuracy is:  0.9512195121951219
# Precision is:  0.9512195121951219
# Recall is:  0.9512195121951219
# F1 score is:  0.9512195121951219

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[16,  0,  0],
#        [ 0, 12,  1],
#        [ 0,  1, 11]], dtype=int64)

# %% [markdown]
# Building the Model-Support Vector Machine---Polynomial Kernel

# %%
svm_poly = SVC(kernel = 'poly', degree = 3)
svm_poly.fit(x_train,y_train)
y_pred = svm_poly.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-812bdf6fe338> in <module>
# ----> 1 svm_poly = SVC(kernel = 'poly', degree = 3)
#       2 svm_poly.fit(x_train,y_train)
#       3 y_pred = svm_poly.predict(x_test)
#
# NameError: name 'SVC' is not defined

# %%
print("Accuracy is: ", accuracy_score(y_test,y_pred))
print("Precision is: ", precision_score(y_test,y_pred, average = 'micro'))
print("Recall is: ", recall_score(y_test,y_pred,  average = 'micro'))
print("F1 score is: ", f1_score(y_test,y_pred,  average = 'micro'))
# Out:
# Accuracy is:  0.9512195121951219
# Precision is:  0.9512195121951219
# Recall is:  0.9512195121951219
# F1 score is:  0.9512195121951219

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[16,  0,  0],
#        [ 0, 12,  1],
#        [ 0,  1, 11]], dtype=int64)

# %% [markdown]
# building the Model-Support Vector Machine---Radial Basis Function Kernel

# %%
svm_radial = SVC(kernel = 'rbf')
svm_radial.fit(x_train,y_train)
y_pred = svm_radial.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-342cfda24181> in <module>
# ----> 1 svm_radial = SVC(kernel = 'rbf')
#       2 svm_radial.fit(x_train,y_train)
#       3 y_pred = svm_radial.predict(x_test)
#
# NameError: name 'SVC' is not defined

# %%
print("Accuracy is: ", accuracy_score(y_test,y_pred))
print("Precision is: ", precision_score(y_test,y_pred, average = 'micro'))
print("Recall is: ", recall_score(y_test,y_pred,  average = 'micro'))
print("F1 score is: ", f1_score(y_test,y_pred,  average = 'micro'))
# Out:
# Accuracy is:  0.9512195121951219
# Precision is:  0.9512195121951219
# Recall is:  0.9512195121951219
# F1 score is:  0.9512195121951219

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[16,  0,  0],
#        [ 0, 12,  1],
#        [ 0,  1, 11]], dtype=int64)

# %% [markdown]
# Building the Model---Rain Forest Classifier Algorithm

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
y_pred = rf.predict(x_test)

# %%
print("Accuracy is: ", accuracy_score(y_test,y_pred))
print("Precision is: ", precision_score(y_test,y_pred,  average = 'micro'))
print("Recall is: ", recall_score(y_test,y_pred,  average = 'micro'))
print("F1 score is: ", f1_score(y_test,y_pred, average = 'micro'))
# Out:
# Accuracy is:  0.9512195121951219
# Precision is:  0.9512195121951219
# Recall is:  0.9512195121951219
# F1 score is:  0.9512195121951219

# %%
confusion_matrix (y_test, y_pred)
# Out:
# array([[16,  0,  0],
#        [ 0, 11,  2],
#        [ 0,  0, 12]], dtype=int64)

# %% [markdown]
# Feature Importance

# %%
pd.Series(rf.feature_importances_, index = x.columns).sort_values(ascending=False)*100
# Out:
# PW      26.288915
# PL      21.347084
# kurt    14.908529
# mean    14.112093
# sum     12.745792
# SL       5.669516
# SW       3.330866
# skew     1.597206
# dtype: float64

# %% [markdown]
# When comparing the f1 scores of the algorithms,then the SVM algorithm with Radial Basis Function kernel lead to neither overfitting nor underfitting model for the classification of species of the iris flower according to the given dataset. Where in the case of logistic regression algorithm the predictions were overfitting. The least fitted among the tested algorithms was the KNN Algorithm.
